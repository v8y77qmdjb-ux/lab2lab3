# %%
import pandas as pd

# Đây là danh sách 50 từ vựng đã được định dạng đúng cấu trúc Python
data = {
    'Từ vựng': [
        '지하철', '버스', '교통카드', '환승', '식당', '편의점', '시장', '할인', '영수증', '배달',
        '대학교', '전공', '과제', '실습', '도서관', '기숙사', '외국인등록증', '월세', '보증금', '인사',
        '약속', '도움', '친구', '문화', '적응', '컴퓨터', '단축키', '인터넷', '휴대폰', '비밀번호',
        '병원', '약국', '건강', '날씨', '우산', '옷차림', '구두', '운동화', '백화점', '우체국',
        '은행', '계좌', '송금', '편지', '여행', '지도', '사진', '영화', '음악', '취미'
    ],
    'Ý nghĩa': [
        'Tàu điện ngầm', 'Xe buýt', 'Thẻ giao thông', 'Trung chuyển', 'Nhà hàng', 'Cửa hàng tiện lợi', 'Chợ', 'Giảm giá', 'Hóa đơn', 'Giao hàng',
        'Đại học', 'Chuyên ngành', 'Bài tập', 'Thực hành', 'Thư viện', 'Ký túc xá', 'Thẻ cư trú', 'Tiền thuê nhà', 'Tiền đặt cọc', 'Chào hỏi',
        'Hẹn', 'Giúp đỡ', 'Bạn bè', 'Văn hóa', 'Thích nghi', 'Máy tính', 'Phím tắt', 'Internet', 'Điện thoại', 'Mật khẩu',
        'Bệnh viện', 'Hiệu thuốc', 'Sức khỏe', 'Thời tiết', 'Ô/Dù', 'Trang phục', 'Giày tây', 'Giày thể thao', 'Trung tâm thương mại', 'Bưu điện',
        'Ngân hàng', 'Tài khoản', 'Chuyển tiền', 'Thư', 'Du lịch', 'Bản đồ', 'Ảnh', 'Phim', 'Âm nhạc', 'Sở thích'
    ]
}

# Tạo DataFrame và lưu thành file CSV
df = pd.DataFrame(data)
df.to_csv('core_words.csv', index=False, encoding='utf-8-sig')

print("Chúc mừng! Bạn đã tạo thành công file core_words.csv")
print("Dưới đây là nội dung file của bạn:")
print(df.head(10)) # Hiển thị thử 10 dòng đầu
# Out:
# Chúc mừng! Bạn đã tạo thành công file core_words.csv
# Dưới đây là nội dung file của bạn:
#   Từ vựng            Ý nghĩa
# 0     지하철      Tàu điện ngầm
# 1      버스            Xe buýt
# 2    교통카드     Thẻ giao thông
# 3      환승       Trung chuyển
# 4      식당           Nhà hàng
# 5     편의점  Cửa hàng tiện lợi
# 6      시장                Chợ
# 7      할인           Giảm giá
# 8     영수증            Hóa đơn
# 9      배달          Giao hàng

# %%
from google.colab import files
files.download('core_words.csv')
